# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib notebook
sns.set()

# %%
from mdet_tests.test_mdet_regression import make_sim

sim = make_sim()

plt.figure()
plt.imshow(np.arcsinh(sim[0][0].image))
ax = plt.gca()
ax.grid(False)
# Out:
# <img src="data:image/png;base64,..." width="640">
